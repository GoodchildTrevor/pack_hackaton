# %% [markdown]
# #Установка и мпорт библиотек

# %%
# !pip install nltk
# !pip install langchain
# !pip install spacy
# !python -m spacy download ru_core_news_sm  # Загрузка модели для русского языка в spacy
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.2.10)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.22 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.22)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.93)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.22->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.22->langchain) (24.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.6)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.22->langchain) (3.0.0)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting ru-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.7.0/ru_core_news_sm-3.7.0-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 33.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from ru-core-news-sm==3.7.0) (3.7.5)
# Requirement already satisfied: pymorphy3>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ru-core-news-sm==3.7.0) (2.0.2)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.7.0) (0.7.2)
# Requirement already satisfied: pymorphy3-dicts-ru in /usr/local/lib/python3.10/dist-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.7.0) (2.4.417150.4580142)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import pandas as pd

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Загрузка стоп-слов
nltk.download('punkt')     # Загрузка списка знаков пунктуации
nltk.download('stopwords') # Загрузка списка стоп-слов для различных языков

import spacy
# Загрузка русского лемматизатора из SpaCy
nlp = spacy.load("ru_core_news_sm")

import re  # Модуль для работы с регулярными выражениями

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity         # Импорт косинусного расстояния

import langchain
from langchain.text_splitter import RecursiveCharacterTextSplitter  # Импорт RecursiveCharacterTextSplitter из langchain для деления на chunks

import gensim.downloader as api
# Загрузка модели GloVe (Global Vectors for Word Representation)
model = api.load("glove-wiki-gigaword-100")

import joblib

import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# #Загружаем данные и словарь с аббревиатурами

# %%
drk = pd.read_csv('merged_drk_df.csv')
cmk = pd.read_csv('merged_cmk_df.csv')
ftl = pd.read_csv('merged_ftl_df.csv')
otr = pd.read_csv('merged_otr_df.csv')
ft = pd.read_csv('merged_ft_df.csv')

df = pd.concat([drk, cmk, ftl, otr, ft], ignore_index=True)

df.columns = ['filename', 'paragraphs', 'link', 'department']
df.head()
# Out:
#                                   filename  \
# 0  Вопросы по грузам с наложенным платежом
# 1  Вопросы по грузам с наложенным платежом
# 2  Вопросы по грузам с наложенным платежом
# 3  Вопросы по грузам с наложенным платежом
# 4  Вопросы по грузам с наложенным платежом
#
#                                           paragraphs  \
# 0  Возможно ли сделать корректировку плательщика ...
# 1  Клиенту необходим осмотр груза, а груз в ЗТУ. ...
# 2  Действия сотрудников, если клиент не согласен ...
# 3  Какие действия сотрудника, если в 1С указано т...
# 4  После оплаты НП и получения груза выяснилось, ...
#
#                                                 link department
# 0  http://confluence/pages/viewpage.action?pageId...        DRK
# 1  http://confluence/pages/viewpage.action?pageId...        DRK
# 2  http://confluence/pages/viewpage.action?pageId...        DRK
# 3  http://confluence/pages/viewpage.action?pageId...        DRK
# 4  http://confluence/pages/viewpage.action?pageId...        DRK

# %%
abr = pd.read_csv('abbr.csv') #аббревиатуры
abr.columns = ['abbr', 'full'] # Переименование столбцов для удобства доступа
abr = abr.set_index('abbr')['full'].to_dict() # Преобразование в словарь для последующего использования при обучении модели

# Добавление дополнительной аббревиатуры в словарь
abr['FTL'] = 'Full Truck Load'
abr['Кыргызстан'] = 'Киргизия'
abr['МГГ'] = 'мелкогабаритный груз'
abr['НТМЦ'] = 'набор товарно-материальных ценностей'
abr['ЗУ'] = 'защитная упаковка'
abr['РТСД'] = 'радио терминал сбора данных'
abr['ШХ'] = 'штрих код'
abr['РС'] = 'регистр сведений'
abr['ТЧ'] = 'табличная часть'
abr['ПФ'] = 'печатная форма'
abr['ТСД'] = 'терминал сбора данных'
abr['НДС'] = 'налог'

# %% [markdown]
# ## Разделим статьи по отделам

# %%
df['department'].unique()
# Out:
# array(['DRK', 'CMK', 'FTL', 'OTR', 'FT'], dtype=object)

# %%
df_DRK = df[df['department'] == 'DRK']
df_CMK = df[df['department'] == 'CMK']
df_FTL = df[df['department'] == 'FTL']
df_OTR = df[df['department'] == 'OTR']
df_FT = df[df['department'] == 'FT']

# %% [markdown]
# #Пропишем необходимые функции для работы

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ###Функция очистки текста

# %%
def clean_text(text):
    # Удаление специальных символов с помощью регулярного выражения
    text = re.sub(r'\W+', ' ', text)
    # Приведение текста к нижнему регистру
    text = text.lower()
    # Лемматизация текста с использованием SpaCy
    doc = nlp(text)
    # Сбор лемматизированных токенов, исключая стоп-слова
    lemmatized_text = ' '.join(token.lemma_ for token in doc if not token.is_stop)
    return lemmatized_text

# %% [markdown]
# ###Функция пополнения словаря модели синонимами для часто используемых слов

# %%
synonyms_cache = abr

def get_synonyms(word):
    if word not in synonyms_cache:
        try:
            sim_words = model.similar_by_word(word)
            synonyms_cache[word] = [word for word, _ in sim_words][:1]  # Store only the first synonym
        except KeyError:
            synonyms_cache[word] = []
    return synonyms_cache[word]

# %% [markdown]
# ###Обогащение текста (контекста и запроса) синонимами

# %%
def expand_with_synonyms(text):
    tokenized = nlp(text)  # Токенизация текста с помощью SpaCy
    expanded_text = []  #список для расширенного текста
    for token in tokenized:
        expanded_text.append(token.text)  # Добавление оригинального токена в расширенный текст
        if token.has_vector:
            synonyms = get_synonyms(token.text)  # Получение синонимов для текущего токена
            if synonyms:
                expanded_text.append(synonyms[0])  # Добавление первого найденного синонима
    return ' '.join(expanded_text)  # Возврат расширенного текста в виде строки

# %% [markdown]
# ### Разбиваем тексты на чанки для лучшего распознавания запроса

# %%
def preprocess_documents(df):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
    chunks = []  # Инициализация списка для хранения обработанных частей текста
    for entry in df:
        title = entry['filename']  # имя файла
        link = entry['link']
        department = entry['department']
        paragraphs = entry['paragraphs']  # текст
        split_chunks = text_splitter.split_text(paragraphs)  # Разделение абзацев на части
        for chunk in split_chunks:
            cleaned_chunk = clean_text(chunk)  # Очистка текста
            expanded_chunk = expand_with_synonyms(cleaned_chunk)  # Расширение текста с помощью синонимов
            chunks.append((title, link, department, expanded_chunk))  # Добавление кортежа (название файла, обработанный текст) в список
    return chunks

# %% [markdown]
# ##Обучение векторизаторов для каждого отдела

# %% [markdown]
# ### Функция векторизации TF-IDF

# %%
def create_and_fit_vectorizer(chunks):
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(chunk for _, _, _, chunk in chunks)  # Применение векторизатора к чанкам
    return vectorizer, X, chunks  # Возврат векторизатора, матрицы TF-IDF и списка чанков

# %% [markdown]
# ### Функция векторизации для каждого отдела

# %%
def model_wrapper(df, model_type):
    documents = df[['filename', 'link', 'department', 'paragraphs']].to_dict(orient='records')
    chunks = preprocess_documents(documents) # Предобработка
    vectorizer, X, chunks = create_and_fit_vectorizer(chunks) # Обучение TF-IDF векторизатора
    return vectorizer, X, chunks   # Возврат векторизатора, матрицы TF-IDF и списка чанков

# %% [markdown]
# ## Проверка работы модели

# %%
#функция обработки запроса из набора тестовых запросов
def execute_queries(df, model_type, vectorizer, X, chunks):
    for item in knowledge_base["вопросы"]:
        if item['отдел'] == model_type:
            query = item['вопрос']  # Получаем текст запроса
            cleaned_query = clean_text(query)  # Очищаем и лемматизируем запрос
            expanded_query = expand_with_synonyms(cleaned_query)  # Расширяем запрос синонимами

            # Векторизуем расширенный запрос
            query_vec = vectorizer.transform([expanded_query])

            # Вычисляем косинусное расстояние между запросом и чанками
            results = cosine_similarity(X, query_vec).flatten()

            # Получаем индексы с наивысшей схожестью
            top_indices = results.argsort()[-5:][::-1]

            # Выводим информацию о запросе и результатах
            print("ДЕЛАЕМ ЗАПРОС: " + query)
            #print("Материалы: " + str(item["материалы"]))
            #print("Отдел: " + str(item["отдел"]))
            print()
            print("РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ: ")
            # Выводим топ-5 наиболее схожих записей
            for i in top_indices:
                similarity_score = results[i]
                print(f"Similarity: {similarity_score:.4f}")
                print(f"Title: {chunks[i][0]}")
                print(f"Link: {chunks[i][1]}")
                print()
        else:
            continue

# %% [markdown]
# # Работа модели и оценка результатов

# %% [markdown]
# ## Обучение векторизаторов

# %%
# Определяем список названий моделей
model_types = ['DRK', 'CMK', 'FTL', 'OTR', 'FT']

# Определяем список датасетов
dfs = [df_DRK, df_CMK, df_FTL, df_OTR, df_FT]

# %%
# Создаем словарь для хранения результатов обучения для каждой комбинации типа модели и объекта DataFrame
results = {}

# Итерируемся по каждому объекту DataFrame и типу модели
for df, model_type in zip(dfs, model_types):
    # Вызываем функцию-обертку для модели, чтобы получить векторизатор, матрицу X и чанки
    vectorizer, X, chunks = model_wrapper(df, model_type)

    # Сохраняем результаты в словаре
    results[(model_type, id(df))] = {
        'vectorizer': vectorizer,  # Векторизатор
        'X': X,  # Матрица признаков X
        'chunks': chunks  # Чанки
    }

# %% [markdown]
# ## Проверка работы векторизаторов

# %% [markdown]
# ### Тестовые данные

# %%
# список текстовых запросов с эталонными документами
knowledge_base = {
    "вопросы": [
        {
            "вопрос": "Как быть если заказчик требует водителя с мед книжкой?",
            "материалы": "На забор груза нужен водитель с мед. книжкой.html",
            "отдел": "DRK"
        },
        {
            "вопрос": "Что входит в доставку в гипермаркеты?",
            "материалы": "Почему тариф на доставку в гипермаркет больше, чем стандартный.html",
            "отдел": "DRK"
        },
        {
            "вопрос": "Как занести контакт в черный список?",
            "материалы": "Клиент просит отключить уведомления (E-mail; ВК; Viber; СМС; Автообзвон; Обзвон).html",
            "отдел": "DRK"
        },
        {
            "вопрос": "Доступна ли перевозка грузов в Киргизию?",
            "материалы": "Курс лекций - База знаний ДРК - База знаний.html",
            "отдел": "DRK"
        },
        {
            "вопрос": "Как найти груз по номеру интернет заказа?",
            "материалы": "Выставление счета в Информации по грузу.html",
            "отдел": "DRK"
        },
        {
            "вопрос": "Как изменить страховую сумму при оформлении груза?",
            "материалы": "Оформление груза в СПО Пегас.html",
            "отдел": "DRK"
        },
        {
            "вопрос": "Возможна ли доставка день в день? Какие интервалы доставки?",
            "материалы": "Планирование доставки - База знаний ДРК - База знаний.html",
            "отдел": "DRK"
        },
        {
            "вопрос": "Что делать, если клиент предоставил новый номер для оповещения?",
            "материалы": "Оповещение о прибытии груза (без доставки) - База знаний ДРК - База знаний.html",
            "отдел": "DRK"
        },
        {
            "вопрос": "Почему не выходят на печать чеки об оплате и ПКО не отображается в реестре?",
            "материалы": "Проверка и проведение оплаты в СПО - База знаний ДРК - База знаний.html",
            "отдел": "DRK"
        },
        {
            "вопрос": "Как клиент может изменить дату авизации в личном кабинете?",
            "материалы": "Личный кабинет клиента (инструкция по применению) - База знаний ДРК - База знаний.html",
            "отдел": "DRK"
        },
        {
            "вопрос": "Клиент спрашивает, для чего мы запрашиваем письма от клиента, при предоставлении ему очередного спец условия",
            "материалы": "Заведение нового клиента и создание спец. условий - База знаний ДРК - База знаний.html",
            "отдел": "DRK"
        },
        {
            "вопрос": "Что написать клиенту, который просит полный доступ к личному кабинету?",
            "материалы": "Шаблоны ответов при обработке почты lk@pecom.ru - База знаний ДРК - База знаний.html",
            "отдел": "DRK"
        },
        {
            "вопрос": "Какая упаковка используется при перевозке автомобильных стекол?",
            "материалы": "Перечень грузов, подлежащих обязательной дополнительной упаковке - CMK - База знаний.html",
            "отдел": "CMK"
        },
        {
            "вопрос": "Сколько времени может проработать подметальная машина?",
            "материалы": "Альбом _Оборудование и инструменты, используемые на участках склада_ - CMK - База знаний.html",
            "отдел": "CMK"
        },
        {
            "вопрос": "Что делать, если клиент отказывается получения сопроводительных документов?",
            "материалы": "Инструкция пользователя «Организация перевозки сопроводительных документов» - CMK - База знаний.html",
            "отдел": "CMK"
        },
        {
           "вопрос": "Какие есть размеры паллетных рам?",
           "материалы": "Альбом _Материалы, используемые на участках склада_ - CMK - База знаний.html",
           "отдел": "CMK"
        },
        {
           "вопрос": "Как осуществить Контроль выполнения НТМЦ?",
           "материалы": "Инструкция пользователя _Создание набора ТМЦ при помощи РТСД_ - CMK - База знаний.html",
           "отдел": "CMK"
        },
        {
           "вопрос": "При отправке грузов в Минск прямые или транзитные рейсы?",
           "материалы": "GLOBAL - Продуктовая книга - База знаний.html",
           "отдел": "CMK"
        },
        {
           "вопрос": "Какие документы нужны для выдачи грузов в Беларусь (для физ. и юр. лиц)?",
           "материалы": "GLOBAL - Продуктовая книга - База знаний.html",
           "отдел": "CMK"
        },
        {
           "вопрос": "Что делать, если клиент выбрал способ подписания Договорных документов на бумаге?",
           "материалы": "Инструкция пользователя «Размещение Договорных документов с Перевозчиком в интерфейсе ПО «Договоры с контрагентами» - CMK - База знаний.html",
           "отдел": "CMK"
        },
        {
           "вопрос": "Как провести обработку упрощенной выдачи по нескольким грузам?",
           "материалы": "Инструкция пользователя _Оформление выдачи груза в СПО_ - CMK - База знаний.html",
           "отдел": "CMK"
        },
        {
           "вопрос": "Когда следует использовать нестандартную защитную упаковку?",
           "материалы": "Стандарт «Дополнительная упаковка груза» - CMK - База знаний.html",
           "отдел": "CMK"
        },
        {
           "вопрос": "Как следует грузить негабаритный груз?",
           "материалы": "Технологическая инструкция _Погрузка и разгрузка ТС с использованием КВП_ - CMK - База знаний.html",
           "отдел": "CMK"
        },
        {
           "вопрос": "Что включает общий вид карточки контрагента?",
           "материалы": "Карточка контрагента - MVP - Full Truck Load - База знаний.html",
           "отдел": "FTL"
        },
        {
           "вопрос": "Как загрузить прайс лист по услугам FTL?",
           "материалы": "Загрузка прайса по услугам FTL в 1С_ TMS Логистика - в проде - Full Truck Load - База знаний.html",
           "отдел": "FTL"
        },
        {
           "вопрос": "Что включает отчет по агентским вознаграждениям FTL?",
           "материалы": "Отчет по агентским вознаграждениям - MVP - Full Truck Load - База знаний.html",
           "отдел": "FTL"
        },
        {
           "вопрос": "Как поступить, если у заявки выставлен статус 'Подтверждение заявки с клиентом'?",
           "материалы": "Алгоритм действий сотрудников по работе с заявкой FTL в 1C_TMS (без документа Рейс) - в проде, версия от 21 года(возможно не актуально) - Full Truck Load - База знаний.html",
           "отдел": "FTL"
        },
        {
           "вопрос": "Как создать новую географическую зону?",
           "материалы": "Редактирование географических зон - Full Truck Load - База знаний.html",
           "отдел": "FTL"
        },
        {
           "вопрос": "Какие бизнес правила страхования актуальны сегодня?",
           "материалы": "Услуги по страхованию груза и срока при перевозке груза по территории РФ и за ее пределами - MVP - Full Truck Load - База знаний.html",
           "отдел": "FTL"
        },
        {
           "вопрос": "Кто изменял документ РасчитатьСпецУсловие_ЗаменаУслуг?",
           "материалы": "ОТР (RND-829).html",
           "отдел": "OTR"
        },
        {
           "вопрос": "Кто наполняет таблицу в базе данных api.RawLog?",
           "материалы": "ОТР (DARCH-1059).html",
           "отдел": "OTR"
        },
        {
           "вопрос": "Когда создана форма документа споВосстановлениеМДИ?",
           "материалы": "ОТР (DBUH-1198).html",
           "отдел": "OTR"
        },
        {
           "вопрос": "Как реализован механизм многопоточной обработки ЭТН?",
           "материалы": "ОТР (DED-51).html",
           "отдел": "OTR"
        },
        {
           "вопрос": "Кто на форму Обработка.ЗачетПереплат добавлял элементы ПериодВыставленияАктов и КонтрагентыНачинаютсяССимволов?",
           "материалы": "ОТР (DPEGAS-32409).html",
           "отдел": "OTR"
        },
        {
           "вопрос": "Что произойдет с просроченными грузами в ПВЗ?",
           "материалы": "ФТ (EPIC-11332).html",
           "отдел": "FT"
        },
        {
           "вопрос": "Возможно ли создание большего количества характеров груза, чем в документе 'Настройка матрица соответствия внутреннего груза'?",
           "материалы": "ФТ (EPIC-10470).html",
           "отдел": "FT"
        },
        {
           "вопрос": "Выставление документа Счет на оплату клиенту, при изменении данных о плательщике, городе оплаты и сумме?",
           "материалы": "ФТ (EPIC-10552).html",
           "отдел": "FT"
        },
        {
           "вопрос": "Возможно ли изменить возвратные данные по грузу, до того, как груз станет возвратным?",
           "материалы": "ФТ (EPIC-10142).html",
           "отдел": "FT"
        },
        {
           "вопрос": "Была ли доработка документа 'Инвентаризация на отправку'?",
           "материалы": "ФТ (EPIC-9495).html",
           "отдел": "FT"
        },
        {
           "вопрос": "Была ли доработка документа 'Приемка'?",
           "материалы": "ФТ (EPIC-13571).html",
           "отдел": "FT"
        }
    ]
}

# %% [markdown]
# ### Проверка результатов выдачи

# %%
# Итерируемся по каждому типу модели и соответствующему ей объекту DataFrame
for model_type, df in zip(model_types, dfs):
    # Получаем соответствующий векторизатор, X и chunks на основе типа модели
    if model_type == 'DRK':
        vectorizer, X, chunks = results[('DRK', id(df_DRK))]['vectorizer'], results[('DRK', id(df_DRK))]['X'], results[('DRK', id(df_DRK))]['chunks']
        execute_queries(df, model_type, vectorizer, X, chunks) #обрабатываем каждый запрос в тестовых данных в зависимости от отдела и выводим результаты
    elif model_type == 'CMK':
        vectorizer, X, chunks = results[('CMK', id(df_CMK))]['vectorizer'], results[('CMK', id(df_CMK))]['X'], results[('CMK', id(df_CMK))]['chunks']
        execute_queries(df, model_type, vectorizer, X, chunks)
    elif model_type == 'FTL':
        vectorizer, X, chunks = results[('FTL', id(df_FTL))]['vectorizer'], results[('FTL', id(df_FTL))]['X'], results[('FTL', id(df_FTL))]['chunks']
        execute_queries(df, model_type, vectorizer, X, chunks)
    elif model_type == 'OTR':
        vectorizer, X, chunks = results[('OTR', id(df_OTR))]['vectorizer'], results[('OTR', id(df_OTR))]['X'], results[('OTR', id(df_OTR))]['chunks']
        execute_queries(df, model_type, vectorizer, X, chunks)
    elif model_type == 'FT':
        vectorizer, X, chunks = results[('FT', id(df_FT))]['vectorizer'], results[('FT', id(df_FT))]['X'], results[('FT', id(df_FT))]['chunks']
        execute_queries(df, model_type, vectorizer, X, chunks)
    else:
        continue
# Out:
# ДЕЛАЕМ ЗАПРОС: Как быть если заказчик требует водителя с мед книжкой?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.4400
# Title: На забор груза нужен водитель с мед. книжкой
# Link: http://confluence/pages/viewpage.action?pageId=88444537
#
# Similarity: 0.2767
# Title: Планирование забора
# Link: http://confluence/pages/viewpage.action?pageId=56001672
#
# Similarity: 0.1858
# Title: Заказчик в печатной форме Поручения экспедитору
# Link: http://confluence/pages/viewpage.action?pageId=140009581
#
# Similarity: 0.1851
# Title: Работа в Информация по грузу
# Link: http://confluence/pages/viewpage.action?pageId=48698796
#
# Similarity: 0.1851
# Title: Выставление счета в Информации по грузу
# Link: http://confluence/pages/viewpage.action?pageId=69372012
#
# ДЕЛАЕМ ЗАПРОС: Что входит в доставку в гипермаркеты?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.3045
# Title: Почему тариф на доставку в гипермаркет больше, чем стандартный
# Link: http://confluence/pages/viewpage.action?pageId=88444500
#
# Similarity: 0.2634
# Title: Курс лекций
# Link: http://confluence/pages/viewpage.action?pageId=48698756
#
# Similarity: 0.2439
# Title: Оформление доставки и дополнительных услуг при доставке
# Link: http://confluence/pages/viewpage.action?pageId=48698778
#
# Similarity: 0.2319
# Title: Оформление груза в СПО Пегас
# Link: http://confluence/pages/viewpage.action?pageId=48698767
#
# Similarity: 0.2043
# Title: Оформление доставки и дополнительных услуг при доставке
# Link: http://confluence/pages/viewpage.action?pageId=48698778
#
# ДЕЛАЕМ ЗАПРОС: Как занести контакт в черный список?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.1703
# Title: Запрет выдачи
# Link: http://confluence/pages/viewpage.action?pageId=53719083
#
# Similarity: 0.1530
# Title: Оформление груза в СПО Пегас
# Link: http://confluence/pages/viewpage.action?pageId=48698767
#
# Similarity: 0.1258
# Title: Клиент просит отключить уведомления (E-mail; ВК; Viber; СМС; Автообзвон; Обзвон)
# Link: http://confluence/pages/viewpage.action?pageId=144606695
#
# Similarity: 0.0957
# Title: Планирование забора
# Link: http://confluence/pages/viewpage.action?pageId=56001672
#
# Similarity: 0.0941
# Title: Клиент просит отключить уведомления (E-mail; ВК; Viber; СМС; Автообзвон; Обзвон)
# Link: http://confluence/pages/viewpage.action?pageId=144606695
#
# ДЕЛАЕМ ЗАПРОС: Доступна ли перевозка грузов в Киргизию?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.1725
# Title: Курс лекций
# Link: http://confluence/pages/viewpage.action?pageId=48698756
#
# Similarity: 0.1685
# Title: Изменение отделения получения груза (перенаправка)
# Link: http://confluence/pages/viewpage.action?pageId=48699485
#
# Similarity: 0.1666
# Title: Курс лекций
# Link: http://confluence/pages/viewpage.action?pageId=48698756
#
# Similarity: 0.1648
# Title: Особенности оформления груза в_из Кыргызской Республики
# Link: http://confluence/pages/viewpage.action?pageId=159786312
#
# Similarity: 0.1644
# Title: Курс лекций
# Link: http://confluence/pages/viewpage.action?pageId=48698756
#
# ДЕЛАЕМ ЗАПРОС: Как найти груз по номеру интернет заказа?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.3454
# Title: Работа в EWA
# Link: http://confluence/pages/viewpage.action?pageId=48706904
#
# Similarity: 0.3303
# Title: Предоставление возвратного акта
# Link: http://confluence/pages/viewpage.action?pageId=80258155
#
# Similarity: 0.2922
# Title: Работа в Информация по грузу
# Link: http://confluence/pages/viewpage.action?pageId=48698796
#
# Similarity: 0.2922
# Title: Выставление счета в Информации по грузу
# Link: http://confluence/pages/viewpage.action?pageId=69372012
#
# Similarity: 0.2872
# Title: Курс лекций
# Link: http://confluence/pages/viewpage.action?pageId=48698756
#
# ДЕЛАЕМ ЗАПРОС: Как изменить страховую сумму при оформлении груза?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.2833
# Title: Шаблоны ответов при обработке почты pecom@pecom
# Link: http://confluence/pages/viewpage.action?pageId=100444970
#
# Similarity: 0.2782
# Title: БЮ Страхование
# Link: http://confluence/pages/viewpage.action?pageId=176383353
#
# Similarity: 0.2472
# Title: Скрипты для чатов
# Link: http://confluence/pages/viewpage.action?pageId=61968932
#
# Similarity: 0.2465
# Title: Вопросы по грузам с наложенным платежом
# Link: http://confluence/pages/viewpage.action?pageId=88444487
#
# Similarity: 0.2102
# Title: Изменение спецификации в грузах с наложенным платежом (изменение суммы НП)
# Link: http://confluence/pages/viewpage.action?pageId=48706039
#
# ДЕЛАЕМ ЗАПРОС: Возможна ли доставка день в день? Какие интервалы доставки?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.5003
# Title: Курс лекций
# Link: http://confluence/pages/viewpage.action?pageId=48698756
#
# Similarity: 0.3231
# Title: Скрипты для чатов
# Link: http://confluence/pages/viewpage.action?pageId=61968932
#
# Similarity: 0.3201
# Title: Оформление доставки и дополнительных услуг при доставке
# Link: http://confluence/pages/viewpage.action?pageId=48698778
#
# Similarity: 0.3200
# Title: Работа в Информация по грузу
# Link: http://confluence/pages/viewpage.action?pageId=48698796
#
# Similarity: 0.3200
# Title: Выставление счета в Информации по грузу
# Link: http://confluence/pages/viewpage.action?pageId=69372012
#
# ДЕЛАЕМ ЗАПРОС: Что делать, если клиент предоставил новый номер для оповещения?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.3313
# Title: Оповещение о прибытии груза (без доставки)
# Link: http://confluence/pages/viewpage.action?pageId=48698825
#
# Similarity: 0.2139
# Title: Вопросы по грузам с наложенным платежом
# Link: http://confluence/pages/viewpage.action?pageId=88444487
#
# Similarity: 0.2059
# Title: Обращения в СФИНКС
# Link: http://confluence/pages/viewpage.action?pageId=48709401
#
# Similarity: 0.1854
# Title: Разрешение типичных проблем при выдаче
# Link: http://confluence/pages/viewpage.action?pageId=48698800
#
# Similarity: 0.1804
# Title: Частые Вопросы - Пользовательская документация ИС
# Link: nan
#
# ДЕЛАЕМ ЗАПРОС: Почему не выходят на печать чеки об оплате и ПКО не отображается в реестре?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.3090
# Title: Проверка и проведение оплаты в СПО
# Link: http://confluence/pages/viewpage.action?pageId=48698832
#
# Similarity: 0.2806
# Title: Инструкция по работе с ККТ, подключенной к СПО _Пегас_ - Пользовательская документация ИС
# Link: nan
#
# Similarity: 0.2803
# Title: Инструкция по работе с ККТ, подключенной к СПО _Пегас_ - Пользовательская документация ИС
# Link: nan
#
# Similarity: 0.2735
# Title: Частые Вопросы - Пользовательская документация ИС
# Link: nan
#
# Similarity: 0.2639
# Title: Частые Вопросы - Пользовательская документация ИС
# Link: nan
#
# ДЕЛАЕМ ЗАПРОС: Как клиент может изменить дату авизации в личном кабинете?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.4457
# Title: Личный кабинет клиента (инструкция по применению)
# Link: http://confluence/pages/viewpage.action?pageId=48698858
#
# Similarity: 0.3702
# Title: Оформление доставки и дополнительных услуг при доставке
# Link: http://confluence/pages/viewpage.action?pageId=48698778
#
# Similarity: 0.3275
# Title: Скрипты для чатов
# Link: http://confluence/pages/viewpage.action?pageId=61968932
#
# Similarity: 0.3135
# Title: Скрипты для чатов
# Link: http://confluence/pages/viewpage.action?pageId=61968932
#
# Similarity: 0.2960
# Title: Личный кабинет клиента (инструкция по применению)
# Link: http://confluence/pages/viewpage.action?pageId=48698858
#
# ДЕЛАЕМ ЗАПРОС: Клиент спрашивает, для чего мы запрашиваем письма от клиента, при предоставлении ему очередного спец условия
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.1643
# Title: Есть ли на складах ПЭК спец. техника для погрузки_разгрузки
# Link: http://confluence/pages/viewpage.action?pageId=122798153
#
# Similarity: 0.1602
# Title: Выставление счета в Информации по грузу
# Link: http://confluence/pages/viewpage.action?pageId=69372012
#
# Similarity: 0.1602
# Title: Работа в Информация по грузу
# Link: http://confluence/pages/viewpage.action?pageId=48698796
#
# Similarity: 0.1579
# Title: Обработка почты lk@pecom
# Link: http://confluence/pages/viewpage.action?pageId=56002210
#
# Similarity: 0.1536
# Title: Индекс груза_Грузоотправитель_Грузополучатель_Плательщик
# Link: http://confluence/pages/viewpage.action?pageId=56003040
#
# ДЕЛАЕМ ЗАПРОС: Что написать клиенту, который просит полный доступ к личному кабинету?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.5010
# Title: Скрипты для чатов
# Link: http://confluence/pages/viewpage.action?pageId=61968932
#
# Similarity: 0.4463
# Title: Шаблоны ответов при обработке почты pecom@pecom
# Link: http://confluence/pages/viewpage.action?pageId=100444970
#
# Similarity: 0.4295
# Title: Шаблоны ответов при обработке почты lk@pecom.ru
# Link: http://confluence/pages/viewpage.action?pageId=109022392
#
# Similarity: 0.4139
# Title: Шаблоны ответов при обработке почты lk@pecom.ru
# Link: http://confluence/pages/viewpage.action?pageId=109022392
#
# Similarity: 0.3794
# Title: Скрипты для чатов
# Link: http://confluence/pages/viewpage.action?pageId=61968932
#
# ДЕЛАЕМ ЗАПРОС: Какая упаковка используется при перевозке автомобильных стекол?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.5442
# Title: Стандарт «Дополнительная упаковка груза»
# Link: http://confluence/pages/viewpage.action?pageId=145958297
#
# Similarity: 0.4187
# Title: Перечень грузов, подлежащих обязательной дополнительной упаковке
# Link: http://confluence/pages/viewpage.action?pageId=176361924
#
# Similarity: 0.3778
# Title: Перечень грузов, подлежащих обязательной дополнительной упаковке
# Link: http://confluence/pages/viewpage.action?pageId=176361924
#
# Similarity: 0.3249
# Title: Перечень грузов, подлежащих обязательной дополнительной упаковке
# Link: http://confluence/pages/viewpage.action?pageId=176361924
#
# Similarity: 0.3208
# Title: Стандарт «Дополнительная упаковка груза»
# Link: http://confluence/pages/viewpage.action?pageId=145958297
#
# ДЕЛАЕМ ЗАПРОС: Сколько времени может проработать подметальная машина?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.2057
# Title: Инструкция пользователя _РТСД Погрузка_
# Link: http://confluence/pages/viewpage.action?pageId=168518410
#
# Similarity: 0.1705
# Title: Инструкция пользователя _Журнал обзвона_
# Link: http://confluence/pages/viewpage.action?pageId=168517817
#
# Similarity: 0.1405
# Title: _ПРОЕКТ_ Инструкция пользователя «Работа с обращениями и инцидентами в СФИНКС»
# Link: http://confluence/pages/viewpage.action?pageId=176384115
#
# Similarity: 0.1219
# Title: Инструкция пользователя _АРМ склад_
# Link: http://confluence/pages/viewpage.action?pageId=180331382
#
# Similarity: 0.1217
# Title: Инструкция пользователя _АРМ склад_
# Link: http://confluence/pages/viewpage.action?pageId=180331382
#
# ДЕЛАЕМ ЗАПРОС: Что делать, если клиент отказывается получения сопроводительных документов?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.4062
# Title: Инструкция пользователя «Организация перевозки сопроводительных документов»
# Link: http://confluence/pages/viewpage.action?pageId=152460320
#
# Similarity: 0.2913
# Title: Инструкция пользователя «Организация перевозки сопроводительных документов»
# Link: http://confluence/pages/viewpage.action?pageId=152460320
#
# Similarity: 0.2909
# Title: Инструкция пользователя «Организация перевозки сопроводительных документов»
# Link: http://confluence/pages/viewpage.action?pageId=152460320
#
# Similarity: 0.2851
# Title: Инструкция пользователя «Организация перевозки сопроводительных документов»
# Link: http://confluence/pages/viewpage.action?pageId=152460320
#
# Similarity: 0.2410
# Title: Инструкция пользователя «Организация перевозки сопроводительных документов»
# Link: http://confluence/pages/viewpage.action?pageId=152460320
#
# ДЕЛАЕМ ЗАПРОС: Какие есть размеры паллетных рам?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.2630
# Title: Стандарт «Привлечение к ответственности работников Компании за повреждение и утрату грузов»
# Link: http://confluence/pages/viewpage.action?pageId=152457370
#
# Similarity: 0.2581
# Title: Стандарт «Привлечение к ответственности работников Компании за повреждение и утрату грузов»
# Link: http://confluence/pages/viewpage.action?pageId=152457370
#
# Similarity: 0.2500
# Title: Стандарт _Палетная рама_
# Link: http://confluence/pages/viewpage.action?pageId=168496722
#
# Similarity: 0.2244
# Title: Стандарт «Дополнительная упаковка груза»
# Link: http://confluence/pages/viewpage.action?pageId=145958297
#
# Similarity: 0.2069
# Title: Технологическая инструкция «Упаковка грузов в палетные рамы»
# Link: http://confluence/pages/viewpage.action?pageId=152457199
#
# ДЕЛАЕМ ЗАПРОС: Как осуществить Контроль выполнения НТМЦ?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.2446
# Title: Инструкция пользователя _АРМ склад_
# Link: http://confluence/pages/viewpage.action?pageId=180331382
#
# Similarity: 0.2446
# Title: Инструкция пользователя _АРМ склад_
# Link: http://confluence/pages/viewpage.action?pageId=180331382
#
# Similarity: 0.1942
# Title: Стандарт «Информационное наполнение этикеток»
# Link: http://confluence/pages/viewpage.action?pageId=145958143
#
# Similarity: 0.1461
# Title: Инструкция пользователя _Создание набора ТМЦ при помощи РТСД_
# Link: http://confluence/pages/viewpage.action?pageId=176386830
#
# Similarity: 0.1431
# Title: Инструкция пользователя _Создание набора ТМЦ при помощи РТСД_
# Link: http://confluence/pages/viewpage.action?pageId=176386830
#
# ДЕЛАЕМ ЗАПРОС: При отправке грузов в Минск прямые или транзитные рейсы?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.2344
# Title: Технологическая инструкция _Погрузка транспортного средства_
# Link: http://confluence/pages/viewpage.action?pageId=152460309
#
# Similarity: 0.2047
# Title: Инструкция пользователя «ТМЦ в рейсе»
# Link: http://confluence/pages/viewpage.action?pageId=155682417
#
# Similarity: 0.1780
# Title: Инструкция пользователя «Оценка кузова транспортного средства»
# Link: http://confluence/pages/viewpage.action?pageId=148319130
#
# Similarity: 0.1732
# Title: Инструкция пользователя «Создание документов «Разгрузка рейса» и «Разгрузка партии» в СПО»
# Link: http://confluence/pages/viewpage.action?pageId=180332737
#
# Similarity: 0.1687
# Title: Инструкция пользователя «Фиксация складских операций по рейсу»
# Link: http://confluence/pages/viewpage.action?pageId=155682422
#
# ДЕЛАЕМ ЗАПРОС: Какие документы нужны для выдачи грузов в Беларусь (для физ. и юр. лиц)?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.3303
# Title: GLOBAL - Продуктовая книга
# Link: http://confluence/display/prod/GLOBAL
#
# Similarity: 0.3091
# Title: GLOBAL - Продуктовая книга
# Link: http://confluence/display/prod/GLOBAL
#
# Similarity: 0.2800
# Title: Концепт ролевой модели прав в новом ЛК
# Link: http://confluence/pages/viewpage.action?pageId=148309130
#
# Similarity: 0.1873
# Title: GLOBAL - Продуктовая книга
# Link: http://confluence/display/prod/GLOBAL
#
# Similarity: 0.1830
# Title: Инструкция пользователя _АРМ склад_
# Link: http://confluence/pages/viewpage.action?pageId=180331382
#
# ДЕЛАЕМ ЗАПРОС: Что делать, если клиент выбрал способ подписания Договорных документов на бумаге?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.2869
# Title: Инструкция пользователя «Размещение Договорных документов с Перевозчиком в интерфейсе ПО «Договоры с контрагентами»
# Link: http://confluence/pages/viewpage.action?pageId=159801845
#
# Similarity: 0.2532
# Title: Инструкция пользователя «Размещение Договорных документов с Перевозчиком в интерфейсе ПО «Договоры с контрагентами»
# Link: http://confluence/pages/viewpage.action?pageId=159801845
#
# Similarity: 0.2501
# Title: Инструкция пользователя «Размещение Договорных документов с Перевозчиком в интерфейсе ПО «Договоры с контрагентами»
# Link: http://confluence/pages/viewpage.action?pageId=159801845
#
# Similarity: 0.2475
# Title: Инструкция пользователя «Размещение нетиповых Договорных документов ТЭО в интерфейсе УПО «Договоры с контрагентами»
# Link: http://confluence/pages/viewpage.action?pageId=176380127
#
# Similarity: 0.2461
# Title: Инструкция пользователя «Размещение типовых Договорных документов ТЭО в интерфейсе УПО «Договоры с контрагентами»
# Link: http://confluence/pages/viewpage.action?pageId=155685968
#
# ДЕЛАЕМ ЗАПРОС: Как провести обработку упрощенной выдачи по нескольким грузам?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.3077
# Title: Инструкция пользователя _Оформление выдачи груза в СПО_
# Link: http://confluence/pages/viewpage.action?pageId=168516685
#
# Similarity: 0.3007
# Title: Инструкция пользователя _Оформление выдачи груза в СПО_
# Link: http://confluence/pages/viewpage.action?pageId=168516685
#
# Similarity: 0.2570
# Title: Инструкция пользователя «Организация перевозки сопроводительных документов»
# Link: http://confluence/pages/viewpage.action?pageId=152460320
#
# Similarity: 0.2553
# Title: Инструкция пользователя _Оформление выдачи груза в СПО_
# Link: http://confluence/pages/viewpage.action?pageId=168516685
#
# Similarity: 0.2243
# Title: Инструкция пользователя _Оформление выдачи груза в СПО_
# Link: http://confluence/pages/viewpage.action?pageId=168516685
#
# ДЕЛАЕМ ЗАПРОС: Когда следует использовать нестандартную защитную упаковку?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.4223
# Title: Стандарт «Дополнительная упаковка груза»
# Link: http://confluence/pages/viewpage.action?pageId=145958297
#
# Similarity: 0.2830
# Title: Технологическая инструкция _Изготовление защитной упаковки_
# Link: http://confluence/pages/viewpage.action?pageId=176379790
#
# Similarity: 0.2788
# Title: Технологическая инструкция _Изготовление защитной упаковки для бочек_
# Link: http://confluence/pages/viewpage.action?pageId=171868476
#
# Similarity: 0.2604
# Title: Стандарт «Дополнительная упаковка груза»
# Link: http://confluence/pages/viewpage.action?pageId=145958297
#
# Similarity: 0.2004
# Title: Перечень грузов, подлежащих обязательной дополнительной упаковке
# Link: http://confluence/pages/viewpage.action?pageId=176361924
#
# ДЕЛАЕМ ЗАПРОС: Как следует грузить негабаритный груз?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.1853
# Title: Инструкция пользователя «Работа с документом «Подбор груза»
# Link: http://confluence/pages/viewpage.action?pageId=155682407
#
# Similarity: 0.1849
# Title: _ПРОЕКТ_ Стандарт качества процесса «Приемка груза на склад»
# Link: http://confluence/pages/viewpage.action?pageId=145958148
#
# Similarity: 0.1810
# Title: Технологическая инструкция _Погрузка транспортного средства_
# Link: http://confluence/pages/viewpage.action?pageId=152460309
#
# Similarity: 0.1724
# Title: Инструкция пользователя «Работа с документом «Подбор груза»
# Link: http://confluence/pages/viewpage.action?pageId=155682407
#
# Similarity: 0.1719
# Title: Инструкция пользователя «Приемка груза»
# Link: http://confluence/pages/viewpage.action?pageId=145958027
#
# ДЕЛАЕМ ЗАПРОС: Что включает общий вид карточки контрагента?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.1759
# Title: Карточка контрагента. Создание адреса доставки
# Link: http://confluence/pages/viewpage.action?pageId=112431456
#
# Similarity: 0.1321
# Title: Карточка контрагента - MVP
# Link: http://confluence/pages/viewpage.action?pageId=157230108
#
# Similarity: 0.1110
# Title: Карточка контрагента - MVP
# Link: http://confluence/pages/viewpage.action?pageId=157230108
#
# Similarity: 0.0994
# Title: Отчет по рейсам - MVP
# Link: http://confluence/pages/viewpage.action?pageId=159781427
#
# Similarity: 0.0974
# Title: Комплекты документов - MVP
# Link: http://confluence/pages/viewpage.action?pageId=159779838
#
# ДЕЛАЕМ ЗАПРОС: Как загрузить прайс лист по услугам FTL?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.3791
# Title: Загрузка прайса по услугам FTL в 1С_ TMS Логистика
# Link: http://confluence/pages/viewpage.action?pageId=112427160
#
# Similarity: 0.3339
# Title: Профили групп доступа
# Link: http://confluence/pages/viewpage.action?pageId=112428555
#
# Similarity: 0.3234
# Title: Документ Рейс - MVP
# Link: http://confluence/pages/viewpage.action?pageId=159786190
#
# Similarity: 0.2956
# Title: АРМ логиста FTL
# Link: http://confluence/pages/viewpage.action?pageId=112432130
#
# Similarity: 0.2788
# Title: АРМ менеджера FTL
# Link: http://confluence/pages/viewpage.action?pageId=112432124
#
# ДЕЛАЕМ ЗАПРОС: Что включает отчет по агентским вознаграждениям FTL?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.3111
# Title: Документ Рейс - MVP
# Link: http://confluence/pages/viewpage.action?pageId=159786190
#
# Similarity: 0.2579
# Title: АРМ логиста FTL
# Link: http://confluence/pages/viewpage.action?pageId=112432130
#
# Similarity: 0.2492
# Title: АРМ менеджера FTL
# Link: http://confluence/pages/viewpage.action?pageId=112432124
#
# Similarity: 0.1980
# Title: Профили групп доступа
# Link: http://confluence/pages/viewpage.action?pageId=112428555
#
# Similarity: 0.1845
# Title: Документ Рейс - MVP
# Link: http://confluence/pages/viewpage.action?pageId=159786190
#
# ДЕЛАЕМ ЗАПРОС: Как поступить, если у заявки выставлен статус 'Подтверждение заявки с клиентом'?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.4914
# Title: Документ Рейс - MVP
# Link: http://confluence/pages/viewpage.action?pageId=159786190
#
# Similarity: 0.4602
# Title: Документ Рейс - MVP
# Link: http://confluence/pages/viewpage.action?pageId=159786190
#
# Similarity: 0.4218
# Title: Документ Рейс - MVP
# Link: http://confluence/pages/viewpage.action?pageId=159786190
#
# Similarity: 0.3404
# Title: Документ Рейс - MVP
# Link: http://confluence/pages/viewpage.action?pageId=159786190
#
# Similarity: 0.3124
# Title: Алгоритм действий сотрудников по работе с заявкой FTL в 1C_TMS (без доку~роде, версия от 21 года(возможно не актуально)
# Link: http://confluence/pages/viewpage.action?pageId=112427174
#
# ДЕЛАЕМ ЗАПРОС: Как создать новую географическую зону?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.6157
# Title: Редактирование географических зон
# Link: http://confluence/pages/viewpage.action?pageId=180323981
#
# Similarity: 0.4534
# Title: Редактирование географических зон
# Link: http://confluence/pages/viewpage.action?pageId=180323981
#
# Similarity: 0.2487
# Title: Редактирование географических зон
# Link: http://confluence/pages/viewpage.action?pageId=180323981
#
# Similarity: 0.1238
# Title: Алгоритм действий сотрудников по работе с заявкой FTL в 1C_TMS (без доку~роде, версия от 21 года(возможно не актуально)
# Link: http://confluence/pages/viewpage.action?pageId=112427174
#
# Similarity: 0.0999
# Title: Карточка контрагента. Создание адреса доставки
# Link: http://confluence/pages/viewpage.action?pageId=112431456
#
# ДЕЛАЕМ ЗАПРОС: Какие бизнес правила страхования актуальны сегодня?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.1502
# Title: Услуги по страхованию груза и срока при перевозке груза по територии РФ и за ее пределами - MVP
# Link: http://confluence/pages/viewpage.action?pageId=159780598
#
# Similarity: 0.0859
# Title: Загрузка прайса по услугам FTL в 1С_ TMS Логистика
# Link: http://confluence/pages/viewpage.action?pageId=112427160
#
# Similarity: 0.0615
# Title: Отчет по рейсам - MVP
# Link: http://confluence/pages/viewpage.action?pageId=159781427
#
# Similarity: 0.0600
# Title: Отчет по рейсам - MVP
# Link: http://confluence/pages/viewpage.action?pageId=159781427
#
# Similarity: 0.0493
# Title: Калькулятор FTL - MVP (но еще не обновлена)
# Link: http://confluence/pages/viewpage.action?pageId=112427142
#
# ДЕЛАЕМ ЗАПРОС: Кто изменял документ РасчитатьСпецУсловие_ЗаменаУслуг?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.1524
# Title: ОТР (DPEGAS-31812)
# Link: http://confluence/pages/viewpage.action?pageId=155685901
#
# Similarity: 0.1292
# Title: ОТР (DPEGAS-31812)
# Link: http://confluence/pages/viewpage.action?pageId=155685901
#
# Similarity: 0.0852
# Title: ОТР (DPEGAS-32778)
# Link: http://confluence/pages/viewpage.action?pageId=159794704
#
# Similarity: 0.0810
# Title: ОТР (DPEGAS-31812)
# Link: http://confluence/pages/viewpage.action?pageId=155685901
#
# Similarity: 0.0662
# Title: ОТР (DPEGAS-36079)
# Link: http://confluence/pages/viewpage.action?pageId=180336739
#
# ДЕЛАЕМ ЗАПРОС: Кто наполняет таблицу в базе данных api.RawLog?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.3009
# Title: ОТР (DARCH-1059)
# Link: http://confluence/pages/viewpage.action?pageId=171881198
#
# Similarity: 0.2610
# Title: ОТР (DARCH-1059)
# Link: http://confluence/pages/viewpage.action?pageId=171881198
#
# Similarity: 0.2098
# Title: ОТР (DARCH-1059)
# Link: http://confluence/pages/viewpage.action?pageId=171881198
#
# Similarity: 0.1762
# Title: ОТР (DARCH-1059)
# Link: http://confluence/pages/viewpage.action?pageId=171881198
#
# Similarity: 0.1556
# Title: ОТР (DARCH-1059)
# Link: http://confluence/pages/viewpage.action?pageId=171881198
#
# ДЕЛАЕМ ЗАПРОС: Когда создана форма документа споВосстановлениеМДИ?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.1550
# Title: ОТР (DBUH-1109)
# Link: http://confluence/pages/viewpage.action?pageId=152450129
#
# Similarity: 0.1426
# Title: ОТР (DBUH-1198)
# Link: http://confluence/pages/viewpage.action?pageId=168500876
#
# Similarity: 0.1260
# Title: ОТР (DPEGAS-33811)
# Link: http://confluence/pages/viewpage.action?pageId=168512419
#
# Similarity: 0.1213
# Title: ОТР (DPEGAS-30867)
# Link: http://confluence/pages/viewpage.action?pageId=148337190
#
# Similarity: 0.1171
# Title: ОТР (DFENICE-4305)
# Link: http://confluence/pages/viewpage.action?pageId=157232690
#
# ДЕЛАЕМ ЗАПРОС: Как реализован механизм многопоточной обработки ЭТН?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.3870
# Title: ОТР (DED-51)
# Link: http://confluence/pages/viewpage.action?pageId=176389783
#
# Similarity: 0.3740
# Title: ОТР (DED-51)
# Link: http://confluence/pages/viewpage.action?pageId=176389783
#
# Similarity: 0.3585
# Title: ОТР (DED-51)
# Link: http://confluence/pages/viewpage.action?pageId=176389783
#
# Similarity: 0.3088
# Title: ОТР (DED-51)
# Link: http://confluence/pages/viewpage.action?pageId=176389783
#
# Similarity: 0.2932
# Title: ОТР (DED-51)
# Link: http://confluence/pages/viewpage.action?pageId=176389783
#
# ДЕЛАЕМ ЗАПРОС: Кто на форму Обработка.ЗачетПереплат добавлял элементы ПериодВыставленияАктов и КонтрагентыНачинаютсяССимволов?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.4650
# Title: ОТР (DPEGAS-32409)
# Link: http://confluence/pages/viewpage.action?pageId=157239997
#
# Similarity: 0.4422
# Title: ОТР (DPEGAS-32409)
# Link: http://confluence/pages/viewpage.action?pageId=157239997
#
# Similarity: 0.2788
# Title: ОТР (DPEGAS-32409)
# Link: http://confluence/pages/viewpage.action?pageId=157239997
#
# Similarity: 0.1503
# Title: ОТР (DPEGAS-34637)
# Link: http://confluence/pages/viewpage.action?pageId=176366117
#
# Similarity: 0.1410
# Title: ОТР (DPEGAS-35587)
# Link: http://confluence/pages/viewpage.action?pageId=176388721
#
# ДЕЛАЕМ ЗАПРОС: Что произойдет с просроченными грузами в ПВЗ?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.1966
# Title: ФТ (EPIC-11531)
# Link: http://confluence/pages/viewpage.action?pageId=157229038&src=contextnavpagetreemode
#
# Similarity: 0.1910
# Title: ФТ (EPIC-11531)
# Link: http://confluence/pages/viewpage.action?pageId=157229038&src=contextnavpagetreemode
#
# Similarity: 0.1883
# Title: ФТ (EPIC-11013)
# Link: http://confluence/pages/viewpage.action?pageId=152441955&src=contextnavpagetreemode
#
# Similarity: 0.1754
# Title: ФТ (EPIC-11332)
# Link: http://confluence/pages/viewpage.action?pageId=159779612&src=contextnavpagetreemode
#
# Similarity: 0.1688
# Title: ФТ (EPIC-12911)
# Link: http://confluence/pages/viewpage.action?pageId=176371921&src=contextnavpagetreemode
#
# ДЕЛАЕМ ЗАПРОС: Возможно ли создание большего количества характеров груза, чем в документе 'Настройка матрица соответствия внутреннего груза'?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.6587
# Title: ФТ (EPIC-10470)
# Link: http://confluence/pages/viewpage.action?pageId=145957446&src=contextnavpagetreemode
#
# Similarity: 0.6267
# Title: ФТ (EPIC-10470)
# Link: http://confluence/pages/viewpage.action?pageId=145957446&src=contextnavpagetreemode
#
# Similarity: 0.6074
# Title: ФТ (EPIC-10470)
# Link: http://confluence/pages/viewpage.action?pageId=145957446&src=contextnavpagetreemode
#
# Similarity: 0.6070
# Title: ФТ (EPIC-11622)
# Link: http://confluence/pages/viewpage.action?pageId=157231291&src=contextnavpagetreemode
#
# Similarity: 0.5963
# Title: ФТ (EPIC-10470)
# Link: http://confluence/pages/viewpage.action?pageId=145957446&src=contextnavpagetreemode
#
# ДЕЛАЕМ ЗАПРОС: Выставление документа Счет на оплату клиенту, при изменении данных о плательщике, городе оплаты и сумме?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.5130
# Title: ФТ (EPIC-10552)
# Link: http://confluence/pages/viewpage.action?pageId=148335508&src=contextnavpagetreemode
#
# Similarity: 0.4354
# Title: ФТ (EPIC-10552)
# Link: http://confluence/pages/viewpage.action?pageId=148335508&src=contextnavpagetreemode
#
# Similarity: 0.4212
# Title: ФТ (EPIC-10552)
# Link: http://confluence/pages/viewpage.action?pageId=148335508&src=contextnavpagetreemode
#
# Similarity: 0.4120
# Title: ФТ (EPIC-10552)
# Link: http://confluence/pages/viewpage.action?pageId=148335508&src=contextnavpagetreemode
#
# Similarity: 0.4078
# Title: ФТ (EPIC-10552)
# Link: http://confluence/pages/viewpage.action?pageId=148335508&src=contextnavpagetreemode
#
# ДЕЛАЕМ ЗАПРОС: Возможно ли изменить возвратные данные по грузу, до того, как груз станет возвратным?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.6117
# Title: ФТ (EPIC-10142)
# Link: http://confluence/pages/viewpage.action?pageId=148335639&src=contextnavpagetreemode
#
# Similarity: 0.4851
# Title: ФТ (EPIC-10146)
# Link: http://confluence/pages/viewpage.action?pageId=145962184&src=contextnavpagetreemode
#
# Similarity: 0.4360
# Title: ФТ (EPIC-10369)
# Link: http://confluence/pages/viewpage.action?pageId=148332001&src=contextnavpagetreemode
#
# Similarity: 0.4235
# Title: ФТ (EPIC-10142)
# Link: http://confluence/pages/viewpage.action?pageId=148335639&src=contextnavpagetreemode
#
# Similarity: 0.4233
# Title: ФТ (EPIC-10142)
# Link: http://confluence/pages/viewpage.action?pageId=148335639&src=contextnavpagetreemode
#
# ДЕЛАЕМ ЗАПРОС: Была ли доработка документа 'Инвентаризация на отправку'?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.5660
# Title: ФТ (EPIC-10568)
# Link: http://confluence/pages/viewpage.action?pageId=148327907&src=contextnavpagetreemode
#
# Similarity: 0.5210
# Title: ФТ (EPIC-10568)
# Link: http://confluence/pages/viewpage.action?pageId=148327907&src=contextnavpagetreemode
#
# Similarity: 0.5202
# Title: ФТ (EPIC-10568)
# Link: http://confluence/pages/viewpage.action?pageId=148327907&src=contextnavpagetreemode
#
# Similarity: 0.4112
# Title: ФТ (EPIC-10568)
# Link: http://confluence/pages/viewpage.action?pageId=148327907&src=contextnavpagetreemode
#
# Similarity: 0.3931
# Title: ФТ (EPIC-10568)
# Link: http://confluence/pages/viewpage.action?pageId=148327907&src=contextnavpagetreemode
#
# ДЕЛАЕМ ЗАПРОС: Была ли доработка документа 'Приемка'?
#
# РЕЗУЛЬТАТЫ РАБОТЫ МОДЕЛИ:
# Similarity: 0.4210
# Title: ФТ (EPIC-12601)
# Link: http://confluence/pages/viewpage.action?pageId=166894935&src=contextnavpagetreemode
#
# Similarity: 0.3967
# Title: ФТ (EPIC-12601)
# Link: http://confluence/pages/viewpage.action?pageId=166894935&src=contextnavpagetreemode
#
# Similarity: 0.3790
# Title: ФТ (EPIC-12601)
# Link: http://confluence/pages/viewpage.action?pageId=166894935&src=contextnavpagetreemode
#
# Similarity: 0.3771
# Title: ФТ (EPIC-13614) Услуга приемки _МЗУ_ и _МЗЯ_
# Link: http://confluence/pages/viewpage.action?pageId=180333457&src=contextnavpagetreemode
#
# Similarity: 0.3717
# Title: ФТ (EPIC-11514)МГГ - создание НТМЦ при сканировании ШК тары(Обработка _ШК ~Ц; Документ Набор ТМЦ(споНаборПаллетныхРам); Документ_ Набор ТМЦ в MS
# Link: http://confluence/pages/viewpage.action?pageId=152459485&src=contextnavpagetreemode

# %% [markdown]
# # Выгружаем векторы и объекты векторизаторов

# %% [markdown]
# ## Новый датасет с векторами

# %%
# Итерируемся по каждому типу модели и соответствующему ей объекту DataFrame
for model_type, df in zip(model_types, dfs):
    # Получаем соответствующую матрицу X и chunks на основе типа модели и создаем DataFrame
    if model_type == 'DRK':
        X, chunks = results[('DRK', id(df_DRK))]['X'], results[('DRK', id(df_DRK))]['chunks']
        drk_chunks = pd.DataFrame(chunks, columns=['title', 'link', 'department', 'chunk'])
        drk_chunks['vectors'] = [list(vector) for vector in X]
    elif model_type == 'CMK':
        X, chunks = results[('CMK', id(df_CMK))]['X'], results[('CMK', id(df_CMK))]['chunks']
        cmk_chunks = pd.DataFrame(chunks, columns=['title', 'link', 'department', 'chunk'])
        cmk_chunks['vectors'] = [list(vector) for vector in X]
    elif model_type == 'FTL':
        X, chunks = results[('FTL', id(df_FTL))]['X'], results[('FTL', id(df_FTL))]['chunks']
        ftl_chunks = pd.DataFrame(chunks, columns=['title', 'link', 'department', 'chunk'])
        ftl_chunks['vectors'] = [list(vector) for vector in X]
    elif model_type == 'OTR':
        X, chunks = results[('OTR', id(df_OTR))]['X'], results[('OTR', id(df_OTR))]['chunks']
        otr_chunks = pd.DataFrame(chunks, columns=['title', 'link', 'department', 'chunk'])
        otr_chunks['vectors'] = [list(vector) for vector in X]
    elif model_type == 'FT':
        X, chunks = results[('FT', id(df_FT))]['X'], results[('FT', id(df_FT))]['chunks']
        ft_chunks = pd.DataFrame(chunks, columns=['title', 'link', 'department', 'chunk'])
        ft_chunks['vectors'] = [list(vector) for vector in X]
    else:
        continue

# %%
cmk_chunks.head()
# Out:
#                                                title  \
# 0  Технологическая инструкция _Проверка данных ко...
# 1  Технологическая инструкция _Проверка данных ко...
# 2  Технологическая инструкция _Проверка данных ко...
# 3  Технологическая инструкция _Проверка данных ко...
# 4  Технологическая инструкция _Проверка данных ко...
#
#                                                 link department  \
# 0  http://confluence/pages/viewpage.action?pageId...        CMK
# 1  http://confluence/pages/viewpage.action?pageId...        CMK
# 2  http://confluence/pages/viewpage.action?pageId...        CMK
# 3  http://confluence/pages/viewpage.action?pageId...        CMK
# 4  http://confluence/pages/viewpage.action?pageId...        CMK
#
#                                                chunk  \
# 0  требование описание операция проверка контраге...
# 1  сотрудник менеджер ответственность обусловить ...
# 2  06 07 07 06 2016 2014 374 353 фз внесение изме...
# 3  осуществляться вручную сайт гибдд http ftp www...
# 4  проверка руководитель компания реализовать авт...
#
#                                              vectors
# 0  [  (0, 135)\t0.15739677465641655\n  (0, 136)\t...
# 1  [  (0, 5699)\t0.060086427737456594\n  (0, 1351...
# 2  [  (0, 3718)\t0.09451856038847756\n  (0, 2361)...
# 3  [  (0, 4094)\t0.08000693683096782\n  (0, 1418)...
# 4  [  (0, 2399)\t0.04132662033890494\n  (0, 1812)...

# %%
drk_chunked_df = drk_chunks.to_csv('drk_chunks.csv', index=False)
cmk_chunked_df = cmk_chunks.to_csv('cmk_chunks.csv', index=False)
ftl_chunked_df = ftl_chunks.to_csv('ftl_chunks.csv', index=False)
otr_chunked_df = otr_chunks.to_csv('otr_chunks.csv', index=False)
ft_chunked_df = ft_chunks.to_csv('ft_chunks.csv', index=False)

# %% [markdown]
# ## Векторизаторы

# %%
def save_results(model_type, vectorizer, X):
    vectorizer_filename = f'vectorizer_{model_type}.joblib'
    X_filename = f'X_{model_type}.joblib' # Имена файлов для сохранения векторизатора и матрицы TF-IDF
    joblib.dump(vectorizer, vectorizer_filename)
    joblib.dump(X, X_filename) # сохранение
    results[(model_type, id(df))] = {'vectorizer': vectorizer, 'X': X, 'chunks': chunks}

# Итерируемся по каждому типу модели и соответствующему ей объекту DataFrame
for model_type, df in zip(model_types, dfs):
    # Запускаем функцию для сохранения векторизатора и матрицы TF-IDF
   save_results(model_type, vectorizer, X)
